# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d = np.load('data/corruptmnist/train_0.npz')

# %%
for i in range(100,150):
    plt.imshow(d['images'][i,:,:], cmap='gray')
    print(d['labels'][i])
    plt.show()
# Out:
# 5
# 7
# 1
# 7
# 1
# 1
# 6
# 3
# 0
# 2
# 9
# 3
# 1
# 1
# 0
# 4
# 9
# 2
# 0
# 0
# 2
# 0
# 2
# 7
# 1
# 8
# 6
# 4
# 1
# 6
# 3
# 4
# 5
# 9
# 1
# 3
# 3
# 8
# 5
# 4
# 7
# 7
# 4
# 2
# 8
# 5
# 8
# 6
# 7
# 3
